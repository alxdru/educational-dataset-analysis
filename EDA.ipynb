# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns

# %%
dataECS=pd.read_csv('ECS.csv')

# %%
dataECS = dataECS.drop('Unnamed: 69',axis=1)

# %%
dataECS = dataECS.drop('Unnamed: 0',axis=1)

# %%
dataCountries=pd.read_csv('ECSCountries.csv')

# %%
ecsGDP = dataECS[dataECS['Indicator Name']=='GDP per capita (current US$)']

# %%
ecsGNI = dataECS[dataECS['Indicator Name']=='GNI per capita, Atlas method (current US$)']

# %%
ecsGDP
# Out:
#              Country Name Country Code                Indicator Name  \
# 81  Europe & Central Asia          ECS  GDP per capita (current US$)
#
#     Indicator Code         1976         1977         1978         1979  \
# 81  NY.GDP.PCAP.CD  3070.760736  3456.521651  4190.853585  5093.121487
#
#            1980         1981  ...          2005          2006          2007  \
# 81  5729.824388  5066.177868  ...  19191.592037  20709.685651  24108.847782
#
#             2008          2009          2010       2011          2012  \
# 81  26352.539224  23084.226956  23536.905927  26015.889  24970.975153
#
#             2013          2014
# 81  25976.554634  26192.934765
#
# [1 rows x 43 columns]

# %%
ecsGNI
# Out:
#              Country Name Country Code  \
# 87  Europe & Central Asia          ECS
#
#                                 Indicator Name  Indicator Code         1976  \
# 87  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  3258.366996
#
#            1977         1978         1979         1980         1981  ...  \
# 87  3475.301139  3927.785695  4856.262525  5812.964978  5842.754964  ...
#
#             2005          2006          2007          2008         2009  \
# 87  19210.646358  20813.907101  22565.301143  24535.092021  24248.80079
#
#             2010          2011          2012          2013          2014
# 87  24465.162052  24919.629832  25201.808107  25886.446275  25883.591689
#
# [1 rows x 43 columns]

# %%
# Out:
#               Country Name Country Code  \
# 0    Europe & Central Asia          ECS
# 1    Europe & Central Asia          ECS
# 2    Europe & Central Asia          ECS
# 3    Europe & Central Asia          ECS
# 4    Europe & Central Asia          ECS
# ..                     ...          ...
# 359  Europe & Central Asia          ECS
# 360  Europe & Central Asia          ECS
# 361  Europe & Central Asia          ECS
# 362  Europe & Central Asia          ECS
# 363  Europe & Central Asia          ECS
#
#                                         Indicator Name        Indicator Code  \
# 0    Adjusted net enrolment rate, primary, both sex...           SE.PRM.TENR
# 1     Adjusted net enrolment rate, primary, female (%)        SE.PRM.TENR.FE
# 2    Adjusted net enrolment rate, primary, gender p...        UIS.NERA.1.GPI
# 3       Adjusted net enrolment rate, primary, male (%)        SE.PRM.TENR.MA
# 4    Adjusted net intake rate to Grade 1 of primary...            UIS.NIRA.1
# ..                                                 ...                   ...
# 359  Youth illiterate population, 15-24 years, male...      UIS.LP.AG15T24.M
# 360  Youth literacy rate, population 15-24 years, b...     SE.ADT.1524.LT.ZS
# 361  Youth literacy rate, population 15-24 years, f...  SE.ADT.1524.LT.FE.ZS
# 362  Youth literacy rate, population 15-24 years, g...  SE.ADT.1524.LT.FM.ZS
# 363  Youth literacy rate, population 15-24 years, m...  SE.ADT.1524.LT.MA.ZS
#
#      1970  1971       1972       1973       1974       1975  ...  \
# 0     NaN   NaN  93.335213  93.054619  93.135818  93.235611  ...
# 1     NaN   NaN        NaN  92.448036  92.436836  92.523933  ...
# 2     NaN   NaN        NaN   0.987300   0.985390   0.985150  ...
# 3     NaN   NaN        NaN  93.637047  93.806908  93.918907  ...
# 4     NaN   NaN        NaN  90.177696  90.357117  90.433632  ...
# ..    ...   ...        ...        ...        ...        ...  ...
# 359   NaN   NaN        NaN        NaN        NaN        NaN  ...
# 360   NaN   NaN        NaN        NaN        NaN        NaN  ...
# 361   NaN   NaN        NaN        NaN        NaN        NaN  ...
# 362   NaN   NaN        NaN        NaN        NaN        NaN  ...
# 363   NaN   NaN        NaN        NaN        NaN        NaN  ...
#
#               2005           2006           2007           2008  \
# 0        96.736832      96.832748      96.862984      97.130112
# 1        96.472656      96.606277      96.733353      96.974167
# 2         0.994680       0.995440       0.997390       0.996870
# 3        96.988518      97.048492      96.986389      97.278526
# 4        91.766197      91.936134      92.683723      92.032272
# ..             ...            ...            ...            ...
# 359  155183.000000  155183.000000  155183.000000  155183.000000
# 360      99.711449      99.711449      99.711449      99.711449
# 361      99.677834      99.677834      99.677834      99.677834
# 362       1.000000       1.000000       1.000000       1.000000
# 363      99.742554      99.742554      99.742554      99.742554
#
#               2009           2010           2011           2012  \
# 0        96.980888      97.274719      97.329178      97.249649
# 1        96.907043      97.232780      97.306313      97.251869
# 2         0.998520       0.999160       0.999540       1.000040
# 3        97.051140      97.314613      97.350899      97.247551
# 4        91.449738      92.639778      93.185226      93.455544
# ..             ...            ...            ...            ...
# 359  155183.000000  155183.000000  155183.000000  155183.000000
# 360      99.711449      99.711449      99.711449      99.711449
# 361      99.677834      99.677834      99.677834      99.677834
# 362       1.000000       1.000000       1.000000       1.000000
# 363      99.742554      99.742554      99.742554      99.742554
#
#               2013           2014
# 0        97.306252      97.022087
# 1        97.291008      97.032494
# 2         0.999690       1.000210
# 3        97.320717      97.012207
# 4        93.420059      89.440102
# ..             ...            ...
# 359  155183.000000  155183.000000
# 360      99.711449      99.711449
# 361      99.677834      99.677834
# 362       1.000000       1.000000
# 363      99.742554      99.742554
#
# [364 rows x 49 columns]
